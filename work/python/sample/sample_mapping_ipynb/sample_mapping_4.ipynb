# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# さいたま市内のコンビニを抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.shop='convenience' and
    poly.name_2='Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0     6795909545   None           None             None               None
# 1     4081142569   None           None             None               None
# 2     6795909641   None           None               13               None
# 3     6898525166   None           None             None               None
# 4     6661634907   None           None             None               None
# ..           ...    ...            ...              ...                ...
# 411   9161249410   None           None             None               None
# 412   9149671133   None           None             None               None
# 413   3744122599   None           None             None               None
# 414   3745337529   None           None             None               None
# 415  12288690630   None           None             None               None
#
#     admin_level aerialway aeroway amenity  area barrier bicycle       brand  \
# 0          None      None    None    None  None    None    None      LAWSON
# 1          None      None    None    None  None    None    None  FamilyMart
# 2          None      None    None    None  None    None    None    セブン-イレブン
# 3          None      None    None    None  None    None    None      ミニストップ
# 4          None      None    None    None  None    None    None    セブン-イレブン
# ..          ...       ...     ...     ...   ...     ...     ...         ...
# 411        None      None    None    None  None    None    None        ローソン
# 412        None      None    None    None  None    None    None        ローソン
# 413        None      None    None    None  None    None    None    セブン-イレブン
# 414        None      None    None    None  None    None    None    セブン-イレブン
# 415        None      None    None    None  None    None    None      LAWSON
#
#     bridge boundary building capital construction covered culvert cutting  \
# 0     None     None     None    None         None    None    None    None
# 1     None     None     None    None         None    None    None    None
# 2     None     None     None    None         None    None    None    None
# 3     None     None     None    None         None    None    None    None
# 4     None     None     None    None         None    None    None    None
# ..     ...      ...      ...     ...          ...     ...     ...     ...
# 411   None     None     None    None         None    None    None    None
# 412   None     None     None    None         None    None    None    None
# 413   None     None     None    None         None    None    None    None
# 414   None     None     None    None         None    None    None    None
# 415   None     None     None    None         None    None    None    None
#
#     denomination disused   ele embankment  foot generator:source harbour  \
# 0           None    None  None       None  None             None    None
# 1           None    None  None       None  None             None    None
# 2           None    None  None       None  None             None    None
# 3           None    None  None       None  None             None    None
# 4           None    None  None       None  None             None    None
# ..           ...     ...   ...        ...   ...              ...     ...
# 411         None    None  None       None  None             None    None
# 412         None    None  None       None  None             None    None
# 413         None    None  None       None  None             None    None
# 414         None    None  None       None  None             None    None
# 415         None    None  None       None  None             None    None
#
#     highway historic horse intermittent junction landuse layer leisure  lock  \
# 0      None     None  None         None     None    None  None    None  None
# 1      None     None  None         None     None    None  None    None  None
# 2      None     None  None         None     None    None  None    None  None
# 3      None     None  None         None     None    None  None    None  None
# 4      None     None  None         None     None    None  None    None  None
# ..      ...      ...   ...          ...      ...     ...   ...     ...   ...
# 411    None     None  None         None     None    None  None    None  None
# 412    None     None  None         None     None    None  None    None  None
# 413    None     None  None         None     None    None  None    None  None
# 414    None     None  None         None     None    None  None    None  None
# 415    None     None  None         None     None    None  None    None  None
#
#     man_made military motorcar              name natural office oneway  \
# 0       None     None     None              ローソン    None   None   None
# 1       None     None     None          ファミリーマート    None   None   None
# 2       None     None     None          セブン-イレブン    None   None   None
# 3       None     None     None            ミニストップ    None   None   None
# 4       None     None     None          セブン-イレブン    None   None   None
# ..       ...      ...      ...               ...     ...    ...    ...
# 411     None     None     None    ローソンさいたま白幡三丁目店    None   None   None
# 412     None     None     None    ローソンさいたま白幡四丁目店    None   None   None
# 413     None     None     None          セブン-イレブン    None   None   None
# 414     None     None     None  セブンイレブンさいたま辻5丁目店    None   None   None
# 415     None     None     None     ローソンさいたま辻五丁目店    None   None   None
#
#     operator place   poi population power power_source public_transport  \
# 0       None  None  None       None  None         None             None
# 1       None  None  None       None  None         None             None
# 2       None  None  None       None  None         None             None
# 3       None  None  None       None  None         None             None
# 4       None  None  None       None  None         None             None
# ..       ...   ...   ...        ...   ...          ...              ...
# 411     None  None  None       None  None         None             None
# 412     None  None  None       None  None         None             None
# 413     None  None  None       None  None         None             None
# 414     None  None  None       None  None         None             None
# 415     None  None  None       None  None         None             None
#
#     railway   ref religion route service         shop sport surface  toll  \
# 0      None  None     None  None    None  convenience  None    None  None
# 1      None  None     None  None    None  convenience  None    None  None
# 2      None  None     None  None    None  convenience  None    None  None
# 3      None  None     None  None    None  convenience  None    None  None
# 4      None  None     None  None    None  convenience  None    None  None
# ..      ...   ...      ...   ...     ...          ...   ...     ...   ...
# 411    None  None     None  None    None  convenience  None    None  None
# 412    None  None     None  None    None  convenience  None    None  None
# 413    None  None     None  None    None  convenience  None    None  None
# 414    None  None     None  None    None  convenience  None    None  None
# 415    None  None     None  None    None  convenience  None    None  None
#
#     tourism tower:type tunnel water waterway wetland width  wood z_order  \
# 0      None       None   None  None     None    None  None  None    None
# 1      None       None   None  None     None    None  None  None    None
# 2      None       None   None  None     None    None  None  None    None
# 3      None       None   None  None     None    None  None  None    None
# 4      None       None   None  None     None    None  None  None    None
# ..      ...        ...    ...   ...      ...     ...   ...   ...     ...
# 411    None       None   None  None     None    None  None  None    None
# 412    None       None   None  None     None    None  None  None    None
# 413    None       None   None  None     None    None  None  None    None
# 414    None       None   None  None     None    None  None  None    None
# 415    None       None   None  None     None    None  None  None    None
#
#                                   way
# 0    POINT (15540181.501 4295281.306)
# 1     POINT (15539656.93 4295032.874)
# 2    POINT (15540543.356 4293188.963)
# 3     POINT (15540249.662 4293338.94)
# 4     POINT (15540245.02 4293894.136)
# ..                                ...
# 411  POINT (15546168.964 4279206.824)
# 412  POINT (15546190.282 4278690.677)
# 413  POINT (15545980.422 4278310.304)
# 414  POINT (15546662.688 4277948.536)
# 415  POINT (15546781.589 4277766.847)
#
# [416 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da8a230542511f9742047d3d8cc12847 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da8a230542511f9742047d3d8cc12847&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da8a230542511f9742047d3d8cc12847 = L.map(
#                 &quot;map_da8a230542511f9742047d3d8cc12847&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef85948f6a392b2e94a9e51f8847c115 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef85948f6a392b2e94a9e51f8847c115.addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#             var marker_13d48db4f75003c4b110f75dfb778382 = L.marker(
#                 [35.96118139973169, 139.5998256],
#                 {
# }
#             ).addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#         var popup_371722a7b4cd5ac9b00577990148e7a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e79a1a10433c9422ace9be6e793152d6 = $(`&lt;div id=&quot;html_e79a1a10433c9422ace9be6e793152d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ローソン&lt;/div&gt;`)[0];
#                 popup_371722a7b4cd5ac9b00577990148e7a4.setContent(html_e79a1a10433c9422ace9be6e793152d6);
#
#
#
#         marker_13d48db4f75003c4b110f75dfb778382.bindPopup(popup_371722a7b4cd5ac9b00577990148e7a4)
#         ;
#
#
#
#
#             var marker_581ee7229d65313a12049b720e7b0763 = L.marker(
#                 [35.95937499973153, 139.5951133],
#                 {
# }
#             ).addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#         var popup_7d65fa8947525f64c898bcd3412e2bed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90700207b6a135c9846e3258231a584b = $(`&lt;div id=&quot;html_90700207b6a135c9846e3258231a584b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ファミリーマート&lt;/div&gt;`)[0];
#                 popup_7d65fa8947525f64c898bcd3412e2bed.setContent(html_90700207b6a135c9846e3258231a584b);
#
#
#
#         marker_581ee7229d65313a12049b720e7b0763.bindPopup(popup_7d65fa8947525f64c898bcd3412e2bed)
#         ;
#
#
#
#
#             var marker_6fa7aa6354eadc6712586cd0cbe60094 = L.marker(
#                 [35.94596629973021, 139.6030762],
#                 {
# }
#             ).addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#         var popup_a5efd8e07404e6e9b308c9eaa53007a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26208f5a772866a7b76fac9625bf1d74 = $(`&lt;div id=&quot;html_26208f5a772866a7b76fac9625bf1d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_a5efd8e07404e6e9b308c9eaa53007a6.setContent(html_26208f5a772866a7b76fac9625bf1d74);
#
#
#
#         marker_6fa7aa6354eadc6712586cd0cbe60094.bindPopup(popup_a5efd8e07404e6e9b308c9eaa53007a6)
#         ;
#
#
#
#
#             var marker_1fe10b7f648d7e88f9b7cfa883010f91 = L.marker(
#                 [35.94705699973032, 139.6004379],
#                 {
# }
#             ).addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#         var popup_2fe76eecb465c2b409a19711d38a059b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc8308bd8bf11f02584e70694e222e7e = $(`&lt;div id=&quot;html_bc8308bd8bf11f02584e70694e222e7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ミニストップ&lt;/div&gt;`)[0];
#                 popup_2fe76eecb465c2b409a19711d38a059b.setContent(html_bc8308bd8bf11f02584e70694e222e7e);
#
#
#
#         marker_1fe10b7f648d7e88f9b7cfa883010f91.bindPopup(popup_2fe76eecb465c2b409a19711d38a059b)
#         ;
#
#
#
#
#             var marker_4cf828ddc92b5234115ca562c601c99e = L.marker(
#                 [35.95109449973071, 139.6003962],
#                 {
# }
#             ).addTo(map_da8a230542511f9742047d3d8cc12847);
#
#
#         var popup_6ee4c573c06186a7a94cf2f6a4d904b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ca21c6b3bb01f0732bed2dc8a9acf58 = $(`&lt;div id=&quot;html_0ca21c6b3bb01f0732bed2dc8a9acf58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;セブン-イレブン&lt;/div&gt;`)[0];
#                 popup_6ee4c573c06186a7a94cf2f6a4d904b1.setContent(html_0ca21c6b3bb01f0732bed2dc8a9acf58);
#
#
#
#         marker_4cf828ddc92b5234115ca562c601c99e.bindPopup(popup_6ee4c573c06186a7a94cf2f6a4d904b1)
#         ;
#
#
#
#
#             var marker_971682fd1db7af7670a3041ebf172e73 = L.marker(
#                 [35.950547599730655, 13
