# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# 埼玉県内のカラオケ店を抽出し, 地図化する.

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
# " "のなかにSQL文を記述
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.amenity='karaoke_box' and
    poly.name_1 = 'Saitama' and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
# sample_mapping_X.ipynbから適切なものを選択し使用する
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#          osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0    7448312670   None           None             None               None
# 1    4352676202   None           None             None               None
# 2   10985271839   None           None             None               None
# 3    3678912618   None           None             None               None
# 4   13154580853   None           None             None               None
# ..          ...    ...            ...              ...                ...
# 71   5751729559   None           None             None               None
# 72   5162718845   None           None             None               None
# 73   5751729526   None           None             None               None
# 74   5736489167   None           None             None               None
# 75   3826171175   None           None             None               None
#
#    admin_level aerialway aeroway      amenity  area barrier bicycle  \
# 0         None      None    None  karaoke_box  None    None    None
# 1         None      None    None  karaoke_box  None    None    None
# 2         None      None    None  karaoke_box  None    None    None
# 3         None      None    None  karaoke_box  None    None    None
# 4         None      None    None  karaoke_box  None    None    None
# ..         ...       ...     ...          ...   ...     ...     ...
# 71        None      None    None  karaoke_box  None    None    None
# 72        None      None    None  karaoke_box  None    None    None
# 73        None      None    None  karaoke_box  None    None    None
# 74        None      None    None  karaoke_box  None    None    None
# 75        None      None    None  karaoke_box  None    None    None
#
#          brand bridge boundary building capital construction covered culvert  \
# 0         None   None     None     None    None         None    None    None
# 1     カラオケバンバン   None     None     None    None         None    None    None
# 2        カラオケ館   None     None     None    None         None    None    None
# 3         None   None     None     None    None         None    None    None
# 4   カラオケ まねきねこ   None     None     None    None         None    None    None
# ..         ...    ...      ...      ...     ...          ...     ...     ...
# 71        None   None     None     None    None         None    None    None
# 72        None   None     None     None    None         None    None    None
# 73        None   None     None     None    None         None    None    None
# 74        None   None     None     None    None         None    None    None
# 75        None   None     None     None    None         None    None    None
#
#    cutting denomination disused   ele embankment  foot generator:source  \
# 0     None         None    None  None       None  None             None
# 1     None         None    None  None       None  None             None
# 2     None         None    None  None       None  None             None
# 3     None         None    None  None       None  None             None
# 4     None         None    None  None       None  None             None
# ..     ...          ...     ...   ...        ...   ...              ...
# 71    None         None    None  None       None  None             None
# 72    None         None    None  None       None  None             None
# 73    None         None    None  None       None  None             None
# 74    None         None    None  None       None  None             None
# 75    None         None    None  None       None  None             None
#
#    harbour highway historic horse intermittent junction landuse layer leisure  \
# 0     None    None     None  None         None     None    None  None    None
# 1     None    None     None  None         None     None    None  None    None
# 2     None    None     None  None         None     None    None  None    None
# 3     None    None     None  None         None     None    None  None    None
# 4     None    None     None  None         None     None    None  None    None
# ..     ...     ...      ...   ...          ...      ...     ...   ...     ...
# 71    None    None     None  None         None     None    None  None    None
# 72    None    None     None  None         None     None    None  None    None
# 73    None    None     None  None         None     None    None  None    None
# 74    None    None     None  None         None     None    None  None    None
# 75    None    None     None  None         None     None    None  None    None
#
#     lock man_made military motorcar        name natural office oneway  \
# 0   None     None     None     None    カラオケ大チャン    None   None   None
# 1   None     None     None     None    カラオケバンバン    None   None   None
# 2   None     None     None     None       カラオケ館    None   None   None
# 3   None     None     None     None       歌うんだ村    None   None   None
# 4   None     None     None     None  カラオケ まねきねこ    None   None   None
# ..   ...      ...      ...      ...         ...     ...    ...    ...
# 71  None     None     None     None          ぽち    None   None   None
# 72  None     None     None     None    BIG ECHO    None   None   None
# 73  None     None     None     None         ゆうこ    None   None   None
# 74  None     None     None     None         Bun    None   None   None
# 75  None     None     None     None        None    None   None   None
#
#    operator place   poi population power power_source public_transport  \
# 0      None  None  None       None  None         None             None
# 1      None  None  None       None  None         None             None
# 2      None  None  None       None  None         None             None
# 3      None  None  None       None  None         None             None
# 4      None  None  None       None  None         None             None
# ..      ...   ...   ...        ...   ...          ...              ...
# 71     None  None  None       None  None         None             None
# 72     None  None  None       None  None         None             None
# 73     None  None  None       None  None         None             None
# 74     None  None  None       None  None         None             None
# 75     None  None  None       None  None         None             None
#
#    railway   ref religion route service  shop sport surface  toll tourism  \
# 0     None  None     None  None    None  None  None    None  None    None
# 1     None  None     None  None    None  None  None    None  None    None
# 2     None  None     None  None    None  None  None    None  None    None
# 3     None  None     None  None    None  None  None    None  None    None
# 4     None  None     None  None    None  None  None    None  None    None
# ..     ...   ...      ...   ...     ...   ...   ...     ...   ...     ...
# 71    None  None     None  None    None  None  None    None  None    None
# 72    None  None     None  None    None  None  None    None  None    None
# 73    None  None     None  None    None  None  None    None  None    None
# 74    None  None     None  None    None  None  None    None  None    None
# 75    None  None     None  None    None  None  None    None  None    None
#
#    tower:type tunnel water waterway wetland width  wood z_order  \
# 0        None   None  None     None    None  None  None    None
# 1        None   None  None     None    None  None  None    None
# 2        None   None  None     None    None  None  None    None
# 3        None   None  None     None    None  None  None    None
# 4        None   None  None     None    None  None  None    None
# ..        ...    ...   ...      ...     ...   ...   ...     ...
# 71       None   None  None     None    None  None  None    None
# 72       None   None  None     None    None  None  None    None
# 73       None   None  None     None    None  None  None    None
# 74       None   None  None     None    None  None  None    None
# 75       None   None  None     None    None  None  None    None
#
#                                  way
# 0   POINT (15543188.329 4300222.371)
# 1   POINT (15532912.115 4324031.278)
# 2     POINT (15536489.2 4298002.295)
# 3    POINT (15562725.39 4277018.165)
# 4   POINT (15538026.611 4298977.594)
# ..                               ...
# 71  POINT (15530701.433 4283629.454)
# 72  POINT (15530718.698 4283406.346)
# 73  POINT (15530549.303 4283719.922)
# 74  POINT (15530451.331 4283782.088)
# 75  POINT (15504645.759 4327223.123)
#
# [76 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51560bfbc31cbc2a80bfdebefb52fc1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51560bfbc31cbc2a80bfdebefb52fc1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51560bfbc31cbc2a80bfdebefb52fc1e = L.map(
#                 &quot;map_51560bfbc31cbc2a80bfdebefb52fc1e&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfd1b0e7a1c1042cb177b3294576e6de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfd1b0e7a1c1042cb177b3294576e6de.addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#             var marker_90bec0df5e4f0affa6d760dcadc997d6 = L.marker(
#                 [35.997100199735236, 139.62683640000003],
#                 {
# }
#             ).addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#         var popup_cbcc169334bc8b9302c2db9730ba49a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7751ce0cb8bdc2dce437008423e8368 = $(`&lt;div id=&quot;html_f7751ce0cb8bdc2dce437008423e8368&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カラオケ大チャン&lt;/div&gt;`)[0];
#                 popup_cbcc169334bc8b9302c2db9730ba49a9.setContent(html_f7751ce0cb8bdc2dce437008423e8368);
#
#
#
#         marker_90bec0df5e4f0affa6d760dcadc997d6.bindPopup(popup_cbcc169334bc8b9302c2db9730ba49a9)
#         ;
#
#
#
#
#             var marker_513f4d4f901af4d245b79fa4e5808883 = L.marker(
#                 [36.16994839975285, 139.53452359999997],
#                 {
# }
#             ).addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#         var popup_e0abf1548b267cf04ca86dfe025b285a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44909ece3ecf169565603150723a153a = $(`&lt;div id=&quot;html_44909ece3ecf169565603150723a153a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カラオケバンバン&lt;/div&gt;`)[0];
#                 popup_e0abf1548b267cf04ca86dfe025b285a.setContent(html_44909ece3ecf169565603150723a153a);
#
#
#
#         marker_513f4d4f901af4d245b79fa4e5808883.bindPopup(popup_e0abf1548b267cf04ca86dfe025b285a)
#         ;
#
#
#
#
#             var marker_d8f171868c72e7e76e50793923683b75 = L.marker(
#                 [35.98096349973364, 139.5666571],
#                 {
# }
#             ).addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#         var popup_c2a5088aaa8fddcd496cf42b78d81ea0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dfc4662c381c7a1ff7eaef1b59adaef = $(`&lt;div id=&quot;html_9dfc4662c381c7a1ff7eaef1b59adaef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カラオケ館&lt;/div&gt;`)[0];
#                 popup_c2a5088aaa8fddcd496cf42b78d81ea0.setContent(html_9dfc4662c381c7a1ff7eaef1b59adaef);
#
#
#
#         marker_d8f171868c72e7e76e50793923683b75.bindPopup(popup_c2a5088aaa8fddcd496cf42b78d81ea0)
#         ;
#
#
#
#
#             var marker_2509850a488426a13aa01b74a008cf48 = L.marker(
#                 [35.8282766997189, 139.8023408],
#                 {
# }
#             ).addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#         var popup_05f122b1e6034e07feb8f1d708ebc5ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd34f92468c43bc80d2a4c4ad1306043 = $(`&lt;div id=&quot;html_dd34f92468c43bc80d2a4c4ad1306043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;歌うんだ村&lt;/div&gt;`)[0];
#                 popup_05f122b1e6034e07feb8f1d708ebc5ac.setContent(html_dd34f92468c43bc80d2a4c4ad1306043);
#
#
#
#         marker_2509850a488426a13aa01b74a008cf48.bindPopup(popup_05f122b1e6034e07feb8f1d708ebc5ac)
#         ;
#
#
#
#
#             var marker_2619e9d82c90044ea0e0c26f2278fef3 = L.marker(
#                 [35.98805289973435, 139.5804679],
#                 {
# }
#             ).addTo(map_51560bfbc31cbc2a80bfdebefb52fc1e);
#
#
#         var popup_b74657e03bc37c370c779c53f4bced4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_932b490df9988777ad5220fd49f7601a = $(`&lt;div id=&quot;html_932b490df9988777ad5220fd49f7601a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;カラオケ まねきねこ&lt;/div&gt;`)[0];
#                 popup_b74657e03bc37c370c779c53f4bced4b.setContent(html_932b490df9988777ad5220fd49f7601a);
#
#
#
#         marker_2619e9d82c90044ea0e0c26f2278fef3.bindPopup(popup_b74657e03bc37c370c779c53f4bced4b)
#         ;
#
#
#
#
#             var marker_9258aac5c6a2350792f8c5c115d6f861 = L.marker(
#                 [35.949
